# %%
import pandas as pd

# %%
import numpy as np

# %%
# %ls
# Out:
#  El volumen de la unidad C es Local Disk
#  El número de serie del volumen es: 0671-FAEA
#
#  Directorio de C:\Users\Monica\PROJECTS
#
# 01/02/2024  15:39    <DIR>          .
# 01/02/2024  15:39    <DIR>          ..
# 29/01/2024  18:40               205 .cache
# 01/02/2024  09:27    <DIR>          .ipynb_checkpoints
# 18/01/2024  19:36            13.731 Escape Room_Solution.ipynb
# 01/02/2024  15:39           589.136 Project Sleep Efficiency.ipynb
# 01/02/2024  15:37            88.274 s1.csv
# 30/01/2024  16:37            41.369 Sleep_Efficiency.csv
# 30/01/2024  13:21            24.072 ss.csv
# 26/01/2024  09:38           268.198 TIBUS (1) (1).ipynb
# 26/01/2024  13:38           306.539 TIBUS (2).ipynb
# 30/01/2024  15:29           507.203 TIBUS (3).ipynb
#                9 archivos      1.838.727 bytes
#                3 dirs  162.507.022.336 bytes libres

# %%
ss = pd.read_csv('ss.csv')
ss.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
ss.tail()
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 368        369  Female   59      Nurse             8.1                 9
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 368                       75             3   Overweight         140/95
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 368          68         7000    Sleep Apnea
# ...

# %%
ss.shape
# Out:
# (373, 13)

# %%
ss.duplicated().any()
# Out:
# False

# %%
ss.columns.str.lower()
# Out:
# Index(['person id', 'gender', 'age', 'occupation', 'sleep duration',
#        'quality of sleep', 'physical activity level', 'stress level',
#        'bmi category', 'blood pressure', 'heart rate', 'daily steps',
#        'sleep disorder'],
#       dtype='object')

# %%
ss.columns = ss.columns.str.replace(' ', '_')
ss.columns
# Out:
# Index(['Person_ID', 'Gender', 'Age', 'Occupation', 'Sleep_Duration',
#        'Quality_of_Sleep', 'Physical_Activity_Level', 'Stress_Level',
#        'BMI_Category', 'Blood_Pressure', 'Heart_Rate', 'Daily_Steps',
#        'Sleep_Disorder'],
#       dtype='object')

# %%
ss.columns = ss.columns.str.lower()
ss.columns
# Out:
# Index(['person_id', 'gender', 'age', 'occupation', 'sleep_duration',
#        'quality_of_sleep', 'physical_activity_level', 'stress_level',
#        'bmi_category', 'blood_pressure', 'heart_rate', 'daily_steps',
#        'sleep_disorder'],
#       dtype='object')

# %%
ss.head()
# Out:
#    person_id gender  age            occupation  sleep_duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    quality_of_sleep  physical_activity_level  stress_level bmi_category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   blood_pressure  heart_rate  daily_steps sleep_disorder
# 0         126/83          77         4200            NaN
# ...

# %%
ss.isna().sum()
# Out:
# person_id                    0
# gender                       0
# age                          0
# occupation                   0
# sleep_duration               0
# quality_of_sleep             0
# physical_activity_level      0
# stress_level                 0
# bmi_category                 0
# blood_pressure               0
# heart_rate                   0
# daily_steps                  0
# sleep_disorder             219
# dtype: int64

# %%
ss.sleep_disorder = ss.sleep_disorder.fillna('None')

# %%
ss.isna().sum()
# Out:
# person_id                  0
# gender                     0
# age                        0
# occupation                 0
# sleep_duration             0
# quality_of_sleep           0
# physical_activity_level    0
# stress_level               0
# bmi_category               0
# blood_pressure             0
# heart_rate                 0
# daily_steps                0
# sleep_disorder             0
# dtype: int64

# %%
ss
# Out:
#      person_id  gender  age            occupation  sleep_duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 368        369  Female   59                 Nurse             8.1
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
#
#      quality_of_sleep  physical_activity_level  stress_level bmi_category  \
# 0                   6                       42             6   Overweight
# ...

# %%
import pandas as pd

# %%
# %ls
# Out:
#  El volumen de la unidad C es Local Disk
#  El número de serie del volumen es: 0671-FAEA
#
#  Directorio de C:\Users\Monica\PROJECTS
#
# 01/02/2024  13:41    <DIR>          .
# 01/02/2024  13:41    <DIR>          ..
# 29/01/2024  18:40               205 .cache
# 01/02/2024  09:27    <DIR>          .ipynb_checkpoints
# 18/01/2024  19:36            13.731 Escape Room_Solution.ipynb
# 01/02/2024  13:41            43.530 Project Sleep Efficiency.ipynb
# 30/01/2024  16:37            41.369 Sleep_Efficiency.csv
# 30/01/2024  13:21            24.072 ss.csv
# 26/01/2024  09:38           268.198 TIBUS (1) (1).ipynb
# 26/01/2024  13:38           306.539 TIBUS (2).ipynb
# 30/01/2024  15:29           507.203 TIBUS (3).ipynb
#                8 archivos      1.204.847 bytes
#                3 dirs  162.547.249.152 bytes libres

# %%
se = pd.read_csv("Sleep_Efficiency.csv")
se
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
se.shape
# Out:
# (452, 15)

# %%
se.columns.str.lower()
# Out:
# Index(['id', 'age', 'gender', 'bedtime', 'wakeup time', 'sleep duration',
#        'sleep efficiency', 'rem sleep percentage', 'deep sleep percentage',
#        'light sleep percentage', 'awakenings', 'caffeine consumption',
#        'alcohol consumption', 'smoking status', 'exercise frequency'],
#       dtype='object')

# %%
se.columns = se.columns.str.replace(' ', '_')
se.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Bedtime', 'Wakeup_time', 'Sleep_duration',
#        'Sleep_efficiency', 'REM_sleep_percentage', 'Deep_sleep_percentage',
#        'Light_sleep_percentage', 'Awakenings', 'Caffeine_consumption',
#        'Alcohol_consumption', 'Smoking_status', 'Exercise_frequency'],
#       dtype='object')

# %%
se.columns = se.columns.str.lower()
se.columns
# Out:
# Index(['id', 'age', 'gender', 'bedtime', 'wakeup_time', 'sleep_duration',
#        'sleep_efficiency', 'rem_sleep_percentage', 'deep_sleep_percentage',
#        'light_sleep_percentage', 'awakenings', 'caffeine_consumption',
#        'alcohol_consumption', 'smoking_status', 'exercise_frequency'],
#       dtype='object')

# %%
se.head()
# Out:
#    id  age  gender              bedtime          wakeup_time  sleep_duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    sleep_efficiency  rem_sleep_percentage  deep_sleep_percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    light_sleep_percentage  awakenings  caffeine_consumption  \
# ...

# %%
se.tail()
# Out:
#       id  age  gender              bedtime          wakeup_time  \
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      sleep_duration  sleep_efficiency  rem_sleep_percentage  \
# 447             7.5              0.91                    22
# 448             6.0              0.74                    28
# 449             8.5              0.55                    20
# 450             7.0              0.76                    18
# 451             7.5              0.63                    22
#
#      deep_sleep_percentage  light_sleep_percentage  awakenings  \
# 447                     57                      21         0.0
# 448                     57                      15         4.0
# ...

# %%
ss.tail()
# Out:
#      person_id  gender  age occupation  sleep_duration  quality_of_sleep  \
# 368        369  Female   59      Nurse             8.1                 9
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
#
#      physical_activity_level  stress_level bmi_category blood_pressure  \
# 368                       75             3   Overweight         140/95
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
#
#      heart_rate  daily_steps sleep_disorder
# 368          68         7000    Sleep Apnea
# ...

# %%
se.duplicated().any()
# Out:
# False

# %%
se.isna().sum()
# Out:
# id                         0
# age                        0
# gender                     0
# bedtime                    0
# wakeup_time                0
# sleep_duration             0
# sleep_efficiency           0
# rem_sleep_percentage       0
# deep_sleep_percentage      0
# light_sleep_percentage     0
# awakenings                20
# caffeine_consumption      25
# alcohol_consumption       14
# smoking_status             0
# exercise_frequency         6
# dtype: int64

# %%
se.awakenings.unique()
# Out:
# array([ 0.,  3.,  1.,  2.,  4., nan])

# %%
se.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      452 non-null    int64
#  1   age                     452 non-null    int64
#  2   gender                  452 non-null    object
#  3   bedtime                 452 non-null    object
#  4   wakeup_time             452 non-null    object
#  5   sleep_duration          452 non-null    float64
#  6   sleep_efficiency        452 non-null    float64
#  7   rem_sleep_percentage    452 non-null    int64
#  8   deep_sleep_percentage   452 non-null    int64
#  9   light_sleep_percentage  452 non-null    int64
#  10  awakenings              432 non-null    float64
#  11  caffeine_consumption    427 non-null    float64
#  12  alcohol_consumption     438 non-null    float64
#  13  smoking_status          452 non-null    object
# ...

# %%
se.awakenings = se.awakenings.fillna(se.awakenings.mean())

# %%
se['awakenings'] = se['awakenings'].apply(lambda x: int(x) if type(x)==float else x)
se['awakenings'].unique()
# Out:
# array([0, 3, 1, 2, 4], dtype=int64)

# %%
se.caffeine_consumption.unique()
# Out:
# array([  0.,  50.,  nan,  25.,  75., 200., 100.])

# %%
se.caffeine_consumption = se.caffeine_consumption.fillna(se.caffeine_consumption.mean())

# %%
se['caffeine_consumption'] = se['caffeine_consumption'].apply(lambda x: int(x) if type(x)==float else x)
se['caffeine_consumption'].unique()
# Out:
# array([  0,  50,  23,  25,  75, 200, 100], dtype=int64)

# %%
se.alcohol_consumption.unique()
# Out:
# array([ 0.,  3.,  5.,  1.,  2., nan,  4.])

# %%
se.alcohol_consumption = se.alcohol_consumption.fillna(se.alcohol_consumption.mean())

# %%
se['alcohol_consumption'] = se['alcohol_consumption'].apply(lambda x: int(x) if type(x)==float else x)
se['alcohol_consumption'].unique()
# Out:
# array([0, 3, 5, 1, 2, 4], dtype=int64)

# %%
se.exercise_frequency.unique()
# Out:
# array([ 3.,  1.,  0.,  5.,  2.,  4., nan])

# %%
se.exercise_frequency = se.exercise_frequency.fillna(se.exercise_frequency.mean())

# %%
se['exercise_frequency'] = se['exercise_frequency'].apply(lambda x: int(x) if type(x)==float else x)
se['exercise_frequency'].unique()
# Out:
# array([3, 1, 0, 5, 2, 4], dtype=int64)

# %%
ss['quality_of_sleep'] = ss['quality_of_sleep'].apply(lambda x: float(x) if type(x)==int else x)
ss['quality_of_sleep'].unique()
# Out:
# array([6., 4., 7., 5., 8., 9.])

# %%
se.isna().sum()
# Out:
# id                        0
# age                       0
# gender                    0
# bedtime                   0
# wakeup_time               0
# sleep_duration            0
# sleep_efficiency          0
# rem_sleep_percentage      0
# deep_sleep_percentage     0
# light_sleep_percentage    0
# awakenings                0
# caffeine_consumption      0
# alcohol_consumption       0
# smoking_status            0
# exercise_frequency        0
# dtype: int64

# %%
ss.isna().sum()
# Out:
# person_id                  0
# gender                     0
# age                        0
# occupation                 0
# sleep_duration             0
# quality_of_sleep           0
# physical_activity_level    0
# stress_level               0
# bmi_category               0
# blood_pressure             0
# heart_rate                 0
# daily_steps                0
# sleep_disorder             0
# dtype: int64

# %%
ss.info()
se.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   person_id                373 non-null    int64
#  1   gender                   373 non-null    object
#  2   age                      373 non-null    int64
#  3   occupation               373 non-null    object
#  4   sleep_duration           373 non-null    float64
#  5   quality_of_sleep         373 non-null    float64
#  6   physical_activity_level  373 non-null    int64
#  7   stress_level             373 non-null    int64
#  8   bmi_category             373 non-null    object
#  9   blood_pressure           373 non-null    object
#  10  heart_rate               373 non-null    int64
#  11  daily_steps              373 non-null    int64
#  12  sleep_disorder           373 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 38.0+ KB
# ...

# %%
se
# Out:
#       id  age  gender              bedtime          wakeup_time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      sleep_duration  sleep_efficiency  rem_sleep_percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
se = se.drop(columns=['bedtime', 'wakeup_time'])

# %%
s = pd.concat([ss, se])
s
# Out:
#      person_id  gender  age            occupation  sleep_duration  \
# 0          1.0    Male   27     Software Engineer             6.1
# 1          2.0    Male   28                Doctor             6.2
# 2          3.0    Male   28                Doctor             6.2
# 3          4.0    Male   28  Sales Representative             5.9
# 4          5.0    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 447        NaN  Female   27                   NaN             7.5
# 448        NaN    Male   52                   NaN             6.0
# 449        NaN  Female   40                   NaN             8.5
# 450        NaN    Male   45                   NaN             7.0
# 451        NaN    Male   18                   NaN             7.5
#
#      quality_of_sleep  physical_activity_level  stress_level bmi_category  \
# 0                 6.0                     42.0           6.0   Overweight
# ...

# %%
s = s.reset_index()
s
# Out:
#      index  person_id  gender  age            occupation  sleep_duration  \
# 0        0        1.0    Male   27     Software Engineer             6.1
# 1        1        2.0    Male   28                Doctor             6.2
# 2        2        3.0    Male   28                Doctor             6.2
# 3        3        4.0    Male   28  Sales Representative             5.9
# 4        4        5.0    Male   28  Sales Representative             5.9
# ..     ...        ...     ...  ...                   ...             ...
# 820    447        NaN  Female   27                   NaN             7.5
# 821    448        NaN    Male   52                   NaN             6.0
# 822    449        NaN  Female   40                   NaN             8.5
# 823    450        NaN    Male   45                   NaN             7.0
# 824    451        NaN    Male   18                   NaN             7.5
#
#      quality_of_sleep  physical_activity_level  stress_level bmi_category  \
# ...

# %%
s = s.drop(columns=['person_id', 'id', 'index'])

# %%
s.head()
# Out:
#   gender  age            occupation  sleep_duration  quality_of_sleep  \
# 0   Male   27     Software Engineer             6.1               6.0
# 1   Male   28                Doctor             6.2               6.0
# 2   Male   28                Doctor             6.2               6.0
# 3   Male   28  Sales Representative             5.9               4.0
# 4   Male   28  Sales Representative             5.9               4.0
#
#    physical_activity_level  stress_level bmi_category blood_pressure  \
# 0                     42.0           6.0   Overweight         126/83
# 1                     60.0           8.0       Normal         125/80
# 2                     60.0           8.0       Normal         125/80
# 3                     30.0           8.0        Obese         140/90
# 4                     30.0           8.0        Obese         140/90
#
#    heart_rate  ...  sleep_disorder sleep_efficiency  rem_sleep_percentage  \
# ...

# %%
s.tail()
# Out:
#      gender  age occupation  sleep_duration  quality_of_sleep  \
# 820  Female   27        NaN             7.5               NaN
# 821    Male   52        NaN             6.0               NaN
# 822  Female   40        NaN             8.5               NaN
# 823    Male   45        NaN             7.0               NaN
# 824    Male   18        NaN             7.5               NaN
#
#      physical_activity_level  stress_level bmi_category blood_pressure  \
# 820                      NaN           NaN          NaN            NaN
# 821                      NaN           NaN          NaN            NaN
# 822                      NaN           NaN          NaN            NaN
# 823                      NaN           NaN          NaN            NaN
# 824                      NaN           NaN          NaN            NaN
#
#      heart_rate  ...  sleep_disorder sleep_efficiency  rem_sleep_percentage  \
# 820         NaN  ...             NaN             0.91                  22.0
# ...

# %%
s.isna().sum()
# Out:
# gender                       0
# age                          0
# occupation                 452
# sleep_duration               0
# quality_of_sleep           452
# physical_activity_level    452
# stress_level               452
# bmi_category               452
# blood_pressure             452
# heart_rate                 452
# daily_steps                452
# sleep_disorder             452
# sleep_efficiency           373
# rem_sleep_percentage       373
# deep_sleep_percentage      373
# light_sleep_percentage     373
# awakenings                 373
# caffeine_consumption       373
# alcohol_consumption        373
# smoking_status             373
# exercise_frequency         373
# dtype: int64

# %%
s.quality_of_sleep.unique()
# Out:
# array([ 6.,  4.,  7.,  5.,  8.,  9., nan])

# %%
se.info()
ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      452 non-null    int64
#  1   age                     452 non-null    int64
#  2   gender                  452 non-null    object
#  3   sleep_duration          452 non-null    float64
#  4   sleep_efficiency        452 non-null    float64
#  5   rem_sleep_percentage    452 non-null    int64
#  6   deep_sleep_percentage   452 non-null    int64
#  7   light_sleep_percentage  452 non-null    int64
#  8   awakenings              452 non-null    int64
#  9   caffeine_consumption    452 non-null    int64
#  10  alcohol_consumption     452 non-null    int64
#  11  smoking_status          452 non-null    object
#  12  exercise_frequency      452 non-null    int64
# dtypes: float64(2), int64(9), object(2)
# memory usage: 46.0+ KB
# ...

# %%
import pandas as pd

s_copy = s.copy()

sleep_efficiency_mean = s_copy['sleep_efficiency'].mean()
s_copy['sleep_efficiency'].fillna(sleep_efficiency_mean, inplace=True)


for index, row in s_copy.iterrows():
    if 4.0 <= row['quality_of_sleep'] <= 9.0:
        s_copy.at[index, 'sleep_efficiency'] = (row['quality_of_sleep'] - 4.0) / 5.0 + 0.4


s_copy.drop('quality_of_sleep', axis=1, inplace=True)


print(s_copy)
# Out:
#      gender  age            occupation  sleep_duration  \
# 0      Male   27     Software Engineer             6.1
# 1      Male   28                Doctor             6.2
# 2      Male   28                Doctor             6.2
# 3      Male   28  Sales Representative             5.9
# 4      Male   28  Sales Representative             5.9
# ..      ...  ...                   ...             ...
# 820  Female   27                   NaN             7.5
# 821    Male   52                   NaN             6.0
# 822  Female   40                   NaN             8.5
# 823    Male   45                   NaN             7.0
# 824    Male   18                   NaN             7.5
#
#      physical_activity_level  stress_level bmi_category blood_pressure  \
# 0                       42.0           6.0   Overweight         126/83
# 1                       60.0           8.0       Normal         125/80
# 2                       60.0           8.0       Normal         125/80
# ...

# %%
s1 = pd.DataFrame(s_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  \
# 0      Male   27     Software Engineer             6.1
# 1      Male   28                Doctor             6.2
# 2      Male   28                Doctor             6.2
# 3      Male   28  Sales Representative             5.9
# 4      Male   28  Sales Representative             5.9
# ..      ...  ...                   ...             ...
# 820  Female   27                   NaN             7.5
# 821    Male   52                   NaN             6.0
# 822  Female   40                   NaN             8.5
# 823    Male   45                   NaN             7.0
# 824    Male   18                   NaN             7.5
#
#      physical_activity_level  stress_level bmi_category blood_pressure  \
# 0                       42.0           6.0   Overweight         126/83
# 1                       60.0           8.0       Normal         125/80
# 2                       60.0           8.0       Normal         125/80
# ...

# %%
s1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gender                   825 non-null    object
#  1   age                      825 non-null    int64
#  2   occupation               373 non-null    object
#  3   sleep_duration           825 non-null    float64
#  4   physical_activity_level  373 non-null    float64
#  5   stress_level             373 non-null    float64
#  6   bmi_category             373 non-null    object
#  7   blood_pressure           373 non-null    object
#  8   heart_rate               373 non-null    float64
#  9   daily_steps              373 non-null    float64
#  10  sleep_disorder           373 non-null    object
#  11  sleep_efficiency         825 non-null    float64
#  12  rem_sleep_percentage     452 non-null    float64
#  13  deep_sleep_percentage    452 non-null    float64
# ...

# %%
import pandas as pd

s1_copy = s1.copy()

s1_copy['exercise_frequency'].fillna(5.0, inplace=True)

s1_copy.drop('physical_activity_level', axis=1, inplace=True)

print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27                   NaN             7.5           NaN
# 821    Male   52                   NaN             6.0           NaN
# 822  Female   40                   NaN             8.5           NaN
# 823    Male   45                   NaN             7.0           NaN
# 824    Male   18                   NaN             7.5           NaN
#
#     bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27                   NaN             7.5           NaN
# 821    Male   52                   NaN             6.0           NaN
# 822  Female   40                   NaN             8.5           NaN
# 823    Male   45                   NaN             7.0           NaN
# 824    Male   18                   NaN             7.5           NaN
#
#     bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1.exercise_frequency.unique()
# Out:
# array([5., 3., 1., 0., 2., 4.])

# %%
s1['exercise_frequency'] = s1['exercise_frequency'].apply(lambda x: int(x) if type(x)==float else x)
s1['exercise_frequency'].unique()
# Out:
# array([5, 3, 1, 0, 2, 4], dtype=int64)

# %%
import pandas as pd
import numpy as np

s1_copy = s1.copy()

existing_categories = s1_copy['bmi_category'].dropna().unique()

s1_copy['bmi_category'] = s1_copy['bmi_category'].apply(lambda x: np.random.choice(existing_categories) if pd.isna(x) else x)


print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27                   NaN             7.5           NaN
# 821    Male   52                   NaN             6.0           NaN
# 822  Female   40                   NaN             8.5           NaN
# 823    Male   45                   NaN             7.0           NaN
# 824    Male   18                   NaN             7.5           NaN
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27                   NaN             7.5           NaN
# 821    Male   52                   NaN             6.0           NaN
# 822  Female   40                   NaN             8.5           NaN
# 823    Male   45                   NaN             7.0           NaN
# 824    Male   18                   NaN             7.5           NaN
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1.occupation.value_counts()
# Out:
# occupation
# Nurse                   72
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
s1.occupation.unique()
# Out:
# array(['Software Engineer', 'Doctor', 'Sales Representative', 'Teacher',
#        'Nurse', 'Engineer', 'Accountant', 'Scientist', 'Lawyer',
#        'Salesperson', 'Manager', nan], dtype=object)

# %%
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27                   NaN             7.5           NaN
# 821    Male   52                   NaN             6.0           NaN
# 822  Female   40                   NaN             8.5           NaN
# 823    Male   45                   NaN             7.0           NaN
# 824    Male   18                   NaN             7.5           NaN
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado 'df' con la columna 'occupation'

# Lista de trabajos disponibles
occupations = ['Software Engineer', 'Doctor', 'Sales Representative', 'Teacher', 'Nurse', 'Engineer', 'Accountant', 'Scientist', 'Lawyer', 'Salesperson', 'Manager']

# Crear una copia del DataFrame para evitar modificar el original
s1_copy = s1.copy()

# Sustituir los NaN en 'occupation' de manera aleatoria entre los trabajos disponibles
s1_copy['occupation'] = s1_copy['occupation'].apply(lambda x: np.random.choice(occupations) if pd.isna(x) else x)

# Mostrar el DataFrame resultante
print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           NaN
# 821    Male   52            Accountant             6.0           NaN
# 822  Female   40                 Nurse             8.5           NaN
# 823    Male   45  Sales Representative             7.0           NaN
# 824    Male   18               Manager             7.5           NaN
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           NaN
# 821    Male   52            Accountant             6.0           NaN
# 822  Female   40                 Nurse             8.5           NaN
# 823    Male   45  Sales Representative             7.0           NaN
# 824    Male   18               Manager             7.5           NaN
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1.sleep_duration.unique()
# Out:
# array([ 6.1,  6.2,  5.9,  6.3,  7.8,  6. ,  6.5,  7.6,  7.7,  7.9,  6.4,
#         7.5,  7.2,  5.8,  6.7,  7.3,  7.4,  7.1,  6.6,  6.9,  8. ,  6.8,
#         8.1,  8.3,  8.5,  8.4,  8.2,  7. , 10. ,  9. ,  5. ,  5.5])

# %%
s1.stress_level.unique()
# Out:
# array([ 6.,  8.,  7.,  4.,  3.,  5., nan])

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado 's1' con las columnas 'sleep_duration' y 'stress_level'
# y deseas realizar la sustitución descrita.

# Crear una copia del DataFrame para evitar modificar el original
s1_copy = s1.copy()

# Crear un diccionario de mapeo entre valores únicos de 'sleep_duration' y 'stress_level'
mapping_dict = {}

for index, row in s1_copy.iterrows():
    sleep_duration = row['sleep_duration']
    stress_level = row['stress_level']
    
    # Verificar si el valor de 'stress_level' no es NaN
    if not pd.isna(stress_level):
        if sleep_duration in mapping_dict:
            # Si el valor de 'sleep_duration' ya está en el diccionario, agregar 'stress_level' a la lista
            mapping_dict[sleep_duration].append(stress_level)
        else:
            # Si es la primera vez que se encuentra el valor de 'sleep_duration', crear una nueva lista
            mapping_dict[sleep_duration] = [stress_level]

# Función para sustituir NaN en 'stress_level' basado en 'sleep_duration'
def replace_nan_stress_level(row):
    sleep_duration = row['sleep_duration']
    stress_level = row['stress_level']
    
    # Verificar si el valor de 'stress_level' es NaN
    if pd.isna(stress_level):
        # Si hay múltiples valores de 'stress_level' para este 'sleep_duration', elegir aleatoriamente uno
        if sleep_duration in mapping_dict:
            stress_level_options = mapping_dict[sleep_duration]
            stress_level = np.random.choice(stress_level_options)
        else:
            # Si no hay información previa, mantener NaN
            stress_level = np.nan
    
    return stress_level

# Aplicar la función de sustitución a la columna 'stress_level'
s1_copy['stress_level'] = s1_copy.apply(replace_nan_stress_level, axis=1)

# Mostrar el DataFrame resultante
print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           NaN
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           NaN
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado 's1' con una columna llamada 'stress_level' que tiene NaN

# Crear una copia del DataFrame para evitar modificar el original
s1_copy = s1.copy()

# Calcular la moda de la columna 'stress_level'
mode_stress_level = s1_copy['stress_level'].mode().iloc[0]

# Sustituir los NaN en 'stress_level' con la moda
s1_copy['stress_level'].fillna(mode_stress_level, inplace=True)

# Mostrar el DataFrame resultante
print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1.stress_level.unique()
# Out:
# array([6., 8., 7., 4., 3., 5.])

# %%
s1.isna().sum()
# Out:
# gender                      0
# age                         0
# occupation                  0
# sleep_duration              0
# stress_level                0
# bmi_category                0
# blood_pressure            452
# heart_rate                452
# daily_steps               452
# sleep_disorder            452
# sleep_efficiency            0
# rem_sleep_percentage      373
# deep_sleep_percentage     373
# light_sleep_percentage    373
# awakenings                373
# caffeine_consumption      373
# alcohol_consumption       373
# smoking_status            373
# exercise_frequency          0
# dtype: int64

# %%
s1.bmi_category.unique()
# Out:
# array(['Overweight', 'Normal', 'Obese', 'Normal Weight'], dtype=object)

# %%
import pandas as pd

s1_copy = s1.copy()

s1_copy['bmi_category'] = s1_copy['bmi_category'].replace('Normal', 'Normal Weight')

print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1.blood_pressure.unique()
# Out:
# array(['126/83', '125/80', '140/90', '120/80', '132/87', '130/86',
#        '117/76', '118/76', '128/85', '131/86', '128/84', '115/75',
#        '135/88', '129/84', '130/85', '115/78', '119/77', '121/79',
#        '125/82', '135/90', '122/80', '142/92', '140/95', '139/91',
#        '118/75', nan], dtype=object)

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado 's1' con las columnas 'bmi_category' y 'blood_pressure'
# y deseas realizar la sustitución descrita.

# Crear una copia del DataFrame para evitar modificar el original
s1_copy = s1.copy()

# Crear un diccionario de mapeo entre valores únicos de 'bmi_category' y 'blood_pressure'
mapping_dict = {}

for index, row in s1_copy.iterrows():
    bmi_category = row['bmi_category']
    blood_pressure = row['blood_pressure']
    
    # Verificar si el valor de 'blood_pressure' no es NaN
    if not pd.isna(blood_pressure):
        if bmi_category in mapping_dict:
            # Si el valor de 'bmi_category' ya está en el diccionario, agregar 'blood_pressure' a la lista
            mapping_dict[bmi_category].append(blood_pressure)
        else:
            # Si es la primera vez que se encuentra el valor de 'bmi_category', crear una nueva lista
            mapping_dict[bmi_category] = [blood_pressure]

# Función para sustituir NaN en 'blood_pressure' basado en 'bmi_category'
def replace_nan_blood_pressure(row):
    bmi_category = row['bmi_category']
    blood_pressure = row['blood_pressure']
    
    # Verificar si el valor de 'blood_pressure' es NaN
    if pd.isna(blood_pressure):
        # Si hay múltiples valores de 'blood_pressure' para este 'bmi_category', elegir aleatoriamente uno
        if bmi_category in mapping_dict:
            blood_pressure_options = mapping_dict[bmi_category]
            blood_pressure = np.random.choice(blood_pressure_options)
        else:
            # Si no hay información previa, mantener NaN
            blood_pressure = np.nan
    
    return blood_pressure

# Aplicar la función de sustitución a la columna 'blood_pressure'
s1_copy['blood_pressure'] = s1_copy.apply(replace_nan_blood_pressure, axis=1)

# Mostrar el DataFrame resultante
print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1.blood_pressure.unique()
# Out:
# array(['126/83', '125/80', '140/90', '120/80', '132/87', '130/86',
#        '117/76', '118/76', '128/85', '131/86', '128/84', '115/75',
#        '135/88', '129/84', '130/85', '115/78', '119/77', '121/79',
#        '125/82', '135/90', '122/80', '142/92', '140/95', '139/91',
#        '118/75'], dtype=object)

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado 's1' con las columnas 'bmi_category' y 'blood_pressure'
# y deseas realizar la sustitución descrita.

# Crear una copia del DataFrame para evitar modificar el original
s1_copy = s1.copy()

# Crear un diccionario de mapeo entre valores únicos de 'bmi_category' y 'blood_pressure'
mapping_dict = {}

for index, row in s1_copy.iterrows():
    blood_pressure = row['blood_pressure']
    heart_rate = row['heart_rate']
    
    # Verificar si el valor de 'blood_pressure' no es NaN
    if not pd.isna(heart_rate):
        if blood_pressure in mapping_dict:
            # Si el valor de 'bmi_category' ya está en el diccionario, agregar 'blood_pressure' a la lista
            mapping_dict[blood_pressure].append(heart_rate)
        else:
            # Si es la primera vez que se encuentra el valor de 'bmi_category', crear una nueva lista
            mapping_dict[blood_pressure] = [heart_rate]

# Función para sustituir NaN en 'blood_pressure' basado en 'bmi_category'
def replace_nan_heart_rate(row):
    blood_pressure = row['blood_pressure']
    heart_rate = row['heart_rate']
    
    # Verificar si el valor de 'blood_pressure' es NaN
    if pd.isna(heart_rate):
        # Si hay múltiples valores de 'blood_pressure' para este 'bmi_category', elegir aleatoriamente uno
        if blood_pressure in mapping_dict:
            heart_rate_options = mapping_dict[blood_pressure]
            heart_rate = np.random.choice(heart_rate_options)
        else:
            # Si no hay información previa, mantener NaN
            heart_rate = np.nan
    
    return heart_rate

# Aplicar la función de sustitución a la columna 'blood_pressure'
s1_copy['heart_rate'] = s1_copy.apply(replace_nan_heart_rate, axis=1)

# Mostrar el DataFrame resultante
print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1.heart_rate.unique()
# Out:
# array([77., 75., 85., 82., 70., 80., 78., 69., 72., 68., 76., 81., 65.,
#        84., 74., 67., 73., 83., 86.])

# %%
s1.daily_steps.unique()
# Out:
# array([ 4200., 10000.,  3000.,  3500.,  8000.,  4000.,  4100.,  6800.,
#         5000.,  7000.,  5500.,  5200.,  5600.,  3300.,  4800.,  7500.,
#         7300.,  6200.,  6000.,  3700.,    nan])

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado 's1' con las columnas 'bmi_category' y 'blood_pressure'
# y deseas realizar la sustitución descrita.

# Crear una copia del DataFrame para evitar modificar el original
s1_copy = s1.copy()

# Crear un diccionario de mapeo entre valores únicos de 'bmi_category' y 'blood_pressure'
mapping_dict = {}

for index, row in s1_copy.iterrows():
    blood_pressure = row['blood_pressure']
    daily_steps = row['daily_steps']
    
    # Verificar si el valor de 'blood_pressure' no es NaN
    if not pd.isna(daily_steps):
        if blood_pressure in mapping_dict:
            # Si el valor de 'bmi_category' ya está en el diccionario, agregar 'blood_pressure' a la lista
            mapping_dict[blood_pressure].append(daily_steps)
        else:
            # Si es la primera vez que se encuentra el valor de 'bmi_category', crear una nueva lista
            mapping_dict[blood_pressure] = [daily_steps]

# Función para sustituir NaN en 'blood_pressure' basado en 'bmi_category'
def replace_nan_daily_steps(row):
    blood_pressure = row['blood_pressure']
    daily_steps = row['daily_steps']
    
    # Verificar si el valor de 'blood_pressure' es NaN
    if pd.isna(daily_steps):
        # Si hay múltiples valores de 'blood_pressure' para este 'bmi_category', elegir aleatoriamente uno
        if blood_pressure in mapping_dict:
            daily_steps_options = mapping_dict[blood_pressure]
            daily_steps = np.random.choice(daily_steps_options)
        else:
            # Si no hay información previa, mantener NaN
            daily_steps = np.nan
    
    return daily_steps

# Aplicar la función de sustitución a la columna 'blood_pressure'
s1_copy['daily_steps'] = s1_copy.apply(replace_nan_daily_steps, axis=1)

# Mostrar el DataFrame resultante
print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado 's1' con las columnas 'bmi_category' y 'blood_pressure'
# y deseas realizar la sustitución descrita.

# Crear una copia del DataFrame para evitar modificar el original
s1_copy = s1.copy()

# Crear un diccionario de mapeo entre valores únicos de 'bmi_category' y 'blood_pressure'
mapping_dict = {}

for index, row in s1_copy.iterrows():
    blood_pressure = row['blood_pressure']
    sleep_disorder = row['sleep_disorder']
    
    # Verificar si el valor de 'blood_pressure' no es NaN
    if not pd.isna(sleep_disorder):
        if blood_pressure in mapping_dict:
            # Si el valor de 'bmi_category' ya está en el diccionario, agregar 'blood_pressure' a la lista
            mapping_dict[blood_pressure].append(sleep_disorder)
        else:
            # Si es la primera vez que se encuentra el valor de 'bmi_category', crear una nueva lista
            mapping_dict[blood_pressure] = [sleep_disorder]

# Función para sustituir NaN en 'blood_pressure' basado en 'bmi_category'
def replace_nan_sleep_disorder(row):
    blood_pressure = row['blood_pressure']
    sleep_disorder = row['sleep_disorder']
    
    # Verificar si el valor de 'blood_pressure' es NaN
    if pd.isna(sleep_disorder):
        # Si hay múltiples valores de 'blood_pressure' para este 'bmi_category', elegir aleatoriamente uno
        if blood_pressure in mapping_dict:
            sleep_disorder_options = mapping_dict[blood_pressure]
            sleep_disorder = np.random.choice(sleep_disorder_options)
        else:
            # Si no hay información previa, mantener NaN
            sleep_disorder = np.nan
    
    return sleep_disorder

# Aplicar la función de sustitución a la columna 'blood_pressure'
s1_copy['sleep_disorder'] = s1_copy.apply(replace_nan_sleep_disorder, axis=1)

# Mostrar el DataFrame resultante
print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1.isna().sum()
# Out:
# gender                      0
# age                         0
# occupation                  0
# sleep_duration              0
# stress_level                0
# bmi_category                0
# blood_pressure              0
# heart_rate                  0
# daily_steps                 0
# sleep_disorder              0
# sleep_efficiency            0
# rem_sleep_percentage      373
# deep_sleep_percentage     373
# light_sleep_percentage    373
# awakenings                373
# caffeine_consumption      373
# alcohol_consumption       373
# smoking_status            373
# exercise_frequency          0
# dtype: int64

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado 's1' con las columnas 'sleep_efficiency', 'rem_sleep_percentage', 'deep_sleep_percentage' y 'light_sleep_percentage'

# Crear una copia del DataFrame para evitar modificar el original
s1_copy = s1.copy()

# Crear un diccionario de mapeo entre valores únicos de 'sleep_efficiency' y 'rem_sleep_percentage'
mapping_dict_rem_sleep = {}

for index, row in s1_copy.iterrows():
    sleep_efficiency = row['sleep_efficiency']
    rem_sleep_percentage = row['rem_sleep_percentage']
    
    # Verificar si el valor de 'rem_sleep_percentage' no es NaN
    if not pd.isna(rem_sleep_percentage):
        if sleep_efficiency in mapping_dict_rem_sleep:
            # Si el valor de 'sleep_efficiency' ya está en el diccionario, agregar 'rem_sleep_percentage' a la lista
            mapping_dict_rem_sleep[sleep_efficiency].append(rem_sleep_percentage)
        else:
            # Si es la primera vez que se encuentra el valor de 'sleep_efficiency', crear una nueva lista
            mapping_dict_rem_sleep[sleep_efficiency] = [rem_sleep_percentage]

# Función para sustituir NaN en 'rem_sleep_percentage' basado en 'sleep_efficiency'
def replace_nan_rem_sleep_percentage(row):
    sleep_efficiency = row['sleep_efficiency']
    rem_sleep_percentage = row['rem_sleep_percentage']
    
    # Verificar si el valor de 'rem_sleep_percentage' es NaN
    if pd.isna(rem_sleep_percentage):
        # Si hay múltiples valores de 'rem_sleep_percentage' para este 'sleep_efficiency', elegir aleatoriamente uno
        if sleep_efficiency in mapping_dict_rem_sleep:
            rem_sleep_percentage_options = mapping_dict_rem_sleep[sleep_efficiency]
            rem_sleep_percentage = np.random.choice(rem_sleep_percentage_options)
        else:
            # Si no hay información previa, mantener NaN
            rem_sleep_percentage = np.nan
    
    return rem_sleep_percentage

# Aplicar la función de sustitución a la columna 'rem_sleep_percentage'
s1_copy['rem_sleep_percentage'] = s1_copy.apply(replace_nan_rem_sleep_percentage, axis=1)

# Crear un diccionario de mapeo entre valores únicos de 'sleep_efficiency' y 'deep_sleep_percentage'
mapping_dict_deep_sleep = {}

for index, row in s1_copy.iterrows():
    sleep_efficiency = row['sleep_efficiency']
    deep_sleep_percentage = row['deep_sleep_percentage']
    
    # Verificar si el valor de 'deep_sleep_percentage' no es NaN
    if not pd.isna(deep_sleep_percentage):
        if sleep_efficiency in mapping_dict_deep_sleep:
            # Si el valor de 'sleep_efficiency' ya está en el diccionario, agregar 'deep_sleep_percentage' a la lista
            mapping_dict_deep_sleep[sleep_efficiency].append(deep_sleep_percentage)
        else:
            # Si es la primera vez que se encuentra el valor de 'sleep_efficiency', crear una nueva lista
            mapping_dict_deep_sleep[sleep_efficiency] = [deep_sleep_percentage]

# Función para sustituir NaN en 'deep_sleep_percentage' basado en 'sleep_efficiency'
def replace_nan_deep_sleep_percentage(row):
    sleep_efficiency = row['sleep_efficiency']
    deep_sleep_percentage = row['deep_sleep_percentage']
    
    # Verificar si el valor de 'deep_sleep_percentage' es NaN
    if pd.isna(deep_sleep_percentage):
        # Si hay múltiples valores de 'deep_sleep_percentage' para este 'sleep_efficiency', elegir aleatoriamente uno
        if sleep_efficiency in mapping_dict_deep_sleep:
            deep_sleep_percentage_options = mapping_dict_deep_sleep[sleep_efficiency]
            deep_sleep_percentage = np.random.choice(deep_sleep_percentage_options)
        else:
            # Si no hay información previa, mantener NaN
            deep_sleep_percentage = np.nan
    
    return deep_sleep_percentage

# Aplicar la función de sustitución a la columna 'deep_sleep_percentage'
s1_copy['deep_sleep_percentage'] = s1_copy.apply(replace_nan_deep_sleep_percentage, axis=1)

# Crear un diccionario de mapeo entre valores únicos de 'sleep_efficiency' y 'light_sleep_percentage'
mapping_dict_light_sleep = {}

for index, row in s1_copy.iterrows():
    sleep_efficiency = row['sleep_efficiency']
    light_sleep_percentage = row['light_sleep_percentage']
    
    # Verificar si el valor de 'light_sleep_percentage' no es NaN
    if not pd.isna(light_sleep_percentage):
        if sleep_efficiency in mapping_dict_light_sleep:
            # Si el valor de 'sleep_efficiency' ya está en el diccionario, agregar 'light_sleep_percentage' a la lista
            mapping_dict_light_sleep[sleep_efficiency].append(light_sleep_percentage)
        else:
            # Si es la primera vez que se encuentra el valor de 'sleep_efficiency', crear una nueva lista
            mapping_dict_light_sleep[sleep_efficiency] = [light_sleep_percentage]

# Función para sustituir NaN en 'light_sleep_percentage' basado en 'sleep_efficiency'
def replace_nan_light_sleep_percentage(row):
    sleep_efficiency = row['sleep_efficiency']
    light_sleep_percentage = row['light_sleep_percentage']
    
    # Verificar si el valor de 'light_sleep_percentage' es NaN
    if pd.isna(light_sleep_percentage):
        # Si hay múltiples valores de 'light_sleep_percentage' para este 'sleep_efficiency', elegir aleatoriamente uno
        if sleep_efficiency in mapping_dict_light_sleep:
            light_sleep_percentage_options = mapping_dict_light_sleep[sleep_efficiency]
            light_sleep_percentage = np.random.choice(light_sleep_percentage_options)
        else:
            # Si no hay información previa, mantener NaN
            light_sleep_percentage = np.nan
    
    return light_sleep_percentage

# Aplicar la función de sustitución a la columna 'light_sleep_percentage'
s1_copy['light_sleep_percentage'] = s1_copy.apply(replace_nan_light_sleep_percentage, axis=1)

# Asegurarse de que la suma de los tres porcentajes sea 100.0
s1_copy['total_sleep_percentage'] = s1_copy['rem_sleep_percentage'] + s1_copy['deep_sleep_percentage'] + s1_copy['light_sleep_percentage']

# Normalizar los porcentajes para que sumen 100.0
s1_copy[['rem_sleep_percentage', 'deep_sleep_percentage', 'light_sleep_percentage']] = s1_copy[['rem_sleep_percentage', 'deep_sleep_percentage', 'light_sleep_percentage']].div(s1_copy['total_sleep_percentage'], axis=0) * 100.0

# Eliminar la columna temporal 'total_sleep_percentage'
s1_copy.drop(columns=['total_sleep_percentage'], inplace=True)

# Mostrar el DataFrame resultante
print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado 's1' con las columnas 'rem_sleep_percentage', 'deep_sleep_percentage' y 'light_sleep_percentage'

# Crear una copia del DataFrame para evitar modificar el original
s1_copy = s1.copy()

# Sustituir NaN por "unknown" en las tres columnas
s1_copy['rem_sleep_percentage'].fillna('unknown', inplace=True)
s1_copy['deep_sleep_percentage'].fillna('unknown', inplace=True)
s1_copy['light_sleep_percentage'].fillna('unknown', inplace=True)

# Mostrar el DataFrame resultante
print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd
import numpy as np

s1_copy = s1.copy()


mapping_dict = {}

for index, row in s1_copy.iterrows():
    sleep_efficiency = row['sleep_efficiency']
    awakenings = row['awakenings']
    
    
    if not pd.isna(awakenings):
        if sleep_efficiency in mapping_dict:
            
            mapping_dict[sleep_efficiency].append(awakenings)
        else:
            
            mapping_dict[sleep_efficiency] = [awakenings]


def replace_nan_awakenings(row):
    sleep_efficiency = row['sleep_efficiency']
    awakenings = row['awakenings']
    
    
    if pd.isna(awakenings):
        
        if sleep_efficiency in mapping_dict:
            awakenings_options = mapping_dict[sleep_efficiency]
            awakenings = np.random.choice(awakenings_options)
        else:
            
            awakenings = np.nan
    
    return awakenings


s1_copy['awakenings'] = s1_copy.apply(replace_nan_awakenings, axis=1)

print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd
import numpy as np

s1_copy = s1.copy()


mapping_dict = {}

for index, row in s1_copy.iterrows():
    sleep_efficiency = row['sleep_efficiency']
    caffeine_consumption = row['caffeine_consumption']
    
    
    if not pd.isna(caffeine_consumption):
        if sleep_efficiency in mapping_dict:
            
            mapping_dict[sleep_efficiency].append(caffeine_consumption)
        else:
            
            mapping_dict[sleep_efficiency] = [caffeine_consumption]


def replace_nan_caffeine_consumption(row):
    sleep_efficiency = row['sleep_efficiency']
    caffeine_consumption = row['caffeine_consumption']
    
    
    if pd.isna(caffeine_consumption):
        
        if sleep_efficiency in mapping_dict:
            caffeine_consumption_options = mapping_dict[sleep_efficiency]
            caffeine_consumption = np.random.choice(caffeine_consumption_options)
        else:
            
            caffeine_consumption = np.nan
    
    return caffeine_consumption


s1_copy['caffeine_consumption'] = s1_copy.apply(replace_nan_caffeine_consumption, axis=1)

print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd
import numpy as np

s1_copy = s1.copy()


mapping_dict = {}

for index, row in s1_copy.iterrows():
    sleep_efficiency = row['sleep_efficiency']
    alcohol_consumption = row['alcohol_consumption']
    
    
    if not pd.isna(alcohol_consumption):
        if sleep_efficiency in mapping_dict:
            
            mapping_dict[sleep_efficiency].append(alcohol_consumption)
        else:
            
            mapping_dict[sleep_efficiency] = [alcohol_consumption]


def replace_nan_alcohol_consumption(row):
    sleep_efficiency = row['sleep_efficiency']
    alcohol_consumption = row['alcohol_consumption']
    
    
    if pd.isna(alcohol_consumption):
        
        if sleep_efficiency in mapping_dict:
            alcohol_consumption_options = mapping_dict[sleep_efficiency]
            alcohol_consumption = np.random.choice(alcohol_consumption_options)
        else:
            
            alcohol_consumption = np.nan
    
    return alcohol_consumption


s1_copy['alcohol_consumption'] = s1_copy.apply(replace_nan_alcohol_consumption, axis=1)

print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd
import numpy as np

s1_copy = s1.copy()


mapping_dict = {}

for index, row in s1_copy.iterrows():
    sleep_efficiency = row['sleep_efficiency']
    smoking_status = row['smoking_status']
    
    
    if not pd.isna(smoking_status):
        if sleep_efficiency in mapping_dict:
            
            mapping_dict[sleep_efficiency].append(smoking_status)
        else:
            
            mapping_dict[sleep_efficiency] = [smoking_status]


def replace_nan_smoking_status(row):
    sleep_efficiency = row['sleep_efficiency']
    smoking_status = row['smoking_status']
    
    
    if pd.isna(smoking_status):
        
        if sleep_efficiency in mapping_dict:
            smoking_status_options = mapping_dict[sleep_efficiency]
            smoking_status = np.random.choice(smoking_status_options)
        else:
            
            smoking_status = np.nan
    
    return smoking_status


s1_copy['smoking_status'] = s1_copy.apply(replace_nan_smoking_status, axis=1)

print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1.isna().sum()
# Out:
# gender                      0
# age                         0
# occupation                  0
# sleep_duration              0
# stress_level                0
# bmi_category                0
# blood_pressure              0
# heart_rate                  0
# daily_steps                 0
# sleep_disorder              0
# sleep_efficiency            0
# rem_sleep_percentage        0
# deep_sleep_percentage       0
# light_sleep_percentage      0
# awakenings                268
# caffeine_consumption      268
# alcohol_consumption       268
# smoking_status            268
# exercise_frequency          0
# dtype: int64

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado 's1' con las columnas mencionadas

# Obtener la moda de cada columna
awakenings_mode = s1['awakenings'].mode()[0]
caffeine_mode = s1['caffeine_consumption'].mode()[0]
alcohol_mode = s1['alcohol_consumption'].mode()[0]
smoking_mode = s1['smoking_status'].mode()[0]

# Sustituir NaN por la moda en cada columna
s1['awakenings'].fillna(awakenings_mode, inplace=True)
s1['caffeine_consumption'].fillna(caffeine_mode, inplace=True)
s1['alcohol_consumption'].fillna(alcohol_mode, inplace=True)
s1['smoking_status'].fillna(smoking_mode, inplace=True)

# Mostrar el DataFrame resultante
print(s1)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd
import numpy as np

s1['rem_sleep_percentage'] = s1['rem_sleep_percentage'].replace('unknown', np.nan)

s1['rem_sleep_percentage'] = pd.to_numeric(s1['rem_sleep_percentage'], errors='coerce')

media_columna = s1['rem_sleep_percentage'].mean()

s1['rem_sleep_percentage'].fillna(media_columna, inplace=True)

print(s1)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd
import numpy as np

s1['deep_sleep_percentage'] = s1['deep_sleep_percentage'].replace('deep_sleep_percentage', np.nan)

s1['deep_sleep_percentage'] = pd.to_numeric(s1['deep_sleep_percentage'], errors='coerce')

media_columna = s1['deep_sleep_percentage'].mean()

s1['deep_sleep_percentage'].fillna(media_columna, inplace=True)

print(s1)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd
import numpy as np

s1['light_sleep_percentage'] = s1['light_sleep_percentage'].replace('light_sleep_percentage', np.nan)

s1['light_sleep_percentage'] = pd.to_numeric(s1['light_sleep_percentage'], errors='coerce')

media_columna = s1['light_sleep_percentage'].mean()

s1['light_sleep_percentage'].fillna(media_columna, inplace=True)

print(s1)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
import pandas as pd

s1['rem_sleep_percentage'] = s1['rem_sleep_percentage'].round(2)
s1['deep_sleep_percentage'] = s1['deep_sleep_percentage'].round(2)
s1['light_sleep_percentage'] = s1['light_sleep_percentage'].round(2)

print(s1)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27     Software Engineer             7.5           3.0
# 821    Male   52            Accountant             6.0           8.0
# 822  Female   40                 Nurse             8.5           3.0
# 823    Male   45  Sales Representative             7.0           3.0
# 824    Male   18               Manager             7.5           4.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# ...

# %%
s1.to_csv('s1.csv', index=False)
