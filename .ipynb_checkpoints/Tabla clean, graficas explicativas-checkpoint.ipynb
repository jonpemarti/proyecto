# %%
import pandas as pd

# %%
# %ls
# Out:
#  El volumen de la unidad C es Local Disk
#  El número de serie del volumen es: 0671-FAEA
#
#  Directorio de C:\Users\Monica\proyecto
#
# 01/02/2024  19:52    <DIR>          .
# 01/02/2024  19:52    <DIR>          ..
# 01/02/2024  15:52    <DIR>          .ipynb_checkpoints
# 01/02/2024  19:52           594.494 Project Sleep Efficiency.ipynb
# 29/01/2024  17:25                10 README.md
# 01/02/2024  19:52            87.267 s1.csv
# 30/01/2024  16:37            41.369 Sleep_Efficiency.csv
# 30/01/2024  13:21            24.072 ss.csv
# 01/02/2024  19:50            70.279 Tabla clean, graficas explicativas.ipynb
#                6 archivos        817.491 bytes
#                3 dirs  162.258.915.328 bytes libres

# %%
s1 = pd.read_csv('s1.csv')
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27           Salesperson             7.5           3.0
# 821    Male   52             Scientist             6.0           8.0
# 822  Female   40                Doctor             8.5           3.0
# 823    Male   45             Scientist             7.0           3.0
# 824    Male   18                Doctor             7.5           5.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# 0       Overweight         126/83        77.0       4200.0            NaN
# 1    Normal Weight         125/80        75.0      10000.0            NaN
# 2    Normal Weight         125/80        75.0      10000.0            NaN
# 3            Obese         140/90        85.0       3000.0    Sleep Apnea
# 4            Obese         140/90        85.0       3000.0    Sleep Apnea
# ..             ...            ...         ...          ...            ...
# 820     Overweight         140/95        68.0      10000.0    Sleep Apnea
# 821  Normal Weight         125/80        65.0       5000.0       Insomnia
# 822  Normal Weight         120/80        70.0       8000.0            NaN
# 823     Overweight         130/85        70.0       6000.0            NaN
# 824          Obese         140/90        85.0       3000.0    Sleep Apnea
#
#      sleep_efficiency  rem_sleep_percentage  deep_sleep_percentage  \
# 0                0.80                 28.57                  56.12
# 1                0.80                 19.15                  63.83
# 2                0.80                 26.67                  57.14
# 3                0.40                 22.53                  54.53
# 4                0.40                 22.53                  54.53
# ..                ...                   ...                    ...
# 820              0.91                 22.00                  57.00
# 821              0.74                 28.00                  57.00
# 822              0.55                 20.00                  32.00
# 823              0.76                 18.00                  72.00
# 824              0.63                 22.00                  23.00
#
#      light_sleep_percentage  awakenings caffeine_consumption  \
# 0                     15.31         2.0                   No
# 1                     17.02         3.0                   Si
# 2                     16.19         1.0                   No
# 3                     22.94         1.0                   No
# 4                     22.94         1.0                   No
# ..                      ...         ...                  ...
# 820                   21.00         0.0                   No
# 821                   15.00         4.0                   Si
# 822                   48.00         1.0                   Si
# 823                   10.00         3.0                   No
# 824                   55.00         1.0                   Si
#
#     alcohol_consumption smoking_status exercise_frequency
# 0                    No            Yes                 Si
# 1                    No            Yes                 Si
# 2                    No             No                 Si
# 3                    No             No                 Si
# 4                    No             No                 Si
# ..                  ...            ...                ...
# 820                  No             No                 Si
# 821                  No             No                 Si
# 822                  Si            Yes                 No
# 823                  No             No                 Si
# 824                  No             No                 Si
#
# [825 rows x 19 columns]

# %%
s1.isna().sum()
# Out:
# gender                      0
# age                         0
# occupation                  0
# sleep_duration              0
# stress_level                0
# bmi_category                0
# blood_pressure              0
# heart_rate                  0
# daily_steps                 0
# sleep_disorder            421
# sleep_efficiency            0
# rem_sleep_percentage        0
# deep_sleep_percentage       0
# light_sleep_percentage      0
# awakenings                  0
# caffeine_consumption        0
# alcohol_consumption         0
# smoking_status              0
# exercise_frequency          0
# dtype: int64

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado 's1' con las columnas 'bmi_category' y 'blood_pressure'
# y deseas realizar la sustitución descrita.

# Crear una copia del DataFrame para evitar modificar el original
s1_copy = s1.copy()

# Crear un diccionario de mapeo entre valores únicos de 'bmi_category' y 'blood_pressure'
mapping_dict = {}

for index, row in s1_copy.iterrows():
    blood_pressure = row['blood_pressure']
    sleep_disorder = row['sleep_disorder']
    
    # Verificar si el valor de 'blood_pressure' no es NaN
    if not pd.isna(sleep_disorder):
        if blood_pressure in mapping_dict:
            # Si el valor de 'bmi_category' ya está en el diccionario, agregar 'blood_pressure' a la lista
            mapping_dict[blood_pressure].append(sleep_disorder)
        else:
            # Si es la primera vez que se encuentra el valor de 'bmi_category', crear una nueva lista
            mapping_dict[blood_pressure] = [sleep_disorder]

# Función para sustituir NaN en 'blood_pressure' basado en 'bmi_category'
def replace_nan_sleep_disorder(row):
    blood_pressure = row['blood_pressure']
    sleep_disorder = row['sleep_disorder']
    
    # Verificar si el valor de 'blood_pressure' es NaN
    if pd.isna(sleep_disorder):
        # Si hay múltiples valores de 'blood_pressure' para este 'bmi_category', elegir aleatoriamente uno
        if blood_pressure in mapping_dict:
            sleep_disorder_options = mapping_dict[blood_pressure]
            sleep_disorder = np.random.choice(sleep_disorder_options)
        else:
            # Si no hay información previa, mantener NaN
            sleep_disorder = np.nan
    
    return sleep_disorder

# Aplicar la función de sustitución a la columna 'blood_pressure'
s1_copy['sleep_disorder'] = s1_copy.apply(replace_nan_sleep_disorder, axis=1)

# Mostrar el DataFrame resultante
print(s1_copy)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27           Salesperson             7.5           3.0
# 821    Male   52             Scientist             6.0           8.0
# 822  Female   40                Doctor             8.5           3.0
# 823    Male   45             Scientist             7.0           3.0
# 824    Male   18                Doctor             7.5           5.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# 0       Overweight         126/83        77.0       4200.0            NaN
# 1    Normal Weight         125/80        75.0      10000.0       Insomnia
# 2    Normal Weight         125/80        75.0      10000.0       Insomnia
# 3            Obese         140/90        85.0       3000.0    Sleep Apnea
# 4            Obese         140/90        85.0       3000.0    Sleep Apnea
# ..             ...            ...         ...          ...            ...
# 820     Overweight         140/95        68.0      10000.0    Sleep Apnea
# 821  Normal Weight         125/80        65.0       5000.0       Insomnia
# 822  Normal Weight         120/80        70.0       8000.0    Sleep Apnea
# 823     Overweight         130/85        70.0       6000.0       Insomnia
# 824          Obese         140/90        85.0       3000.0    Sleep Apnea
#
#      sleep_efficiency  rem_sleep_percentage  deep_sleep_percentage  \
# 0                0.80                 28.57                  56.12
# 1                0.80                 19.15                  63.83
# 2                0.80                 26.67                  57.14
# 3                0.40                 22.53                  54.53
# 4                0.40                 22.53                  54.53
# ..                ...                   ...                    ...
# 820              0.91                 22.00                  57.00
# 821              0.74                 28.00                  57.00
# 822              0.55                 20.00                  32.00
# 823              0.76                 18.00                  72.00
# 824              0.63                 22.00                  23.00
#
#      light_sleep_percentage  awakenings caffeine_consumption  \
# 0                     15.31         2.0                   No
# 1                     17.02         3.0                   Si
# 2                     16.19         1.0                   No
# 3                     22.94         1.0                   No
# 4                     22.94         1.0                   No
# ..                      ...         ...                  ...
# 820                   21.00         0.0                   No
# 821                   15.00         4.0                   Si
# 822                   48.00         1.0                   Si
# 823                   10.00         3.0                   No
# 824                   55.00         1.0                   Si
#
#     alcohol_consumption smoking_status exercise_frequency
# 0                    No            Yes                 Si
# 1                    No            Yes                 Si
# 2                    No             No                 Si
# 3                    No             No                 Si
# 4                    No             No                 Si
# ..                  ...            ...                ...
# 820                  No             No                 Si
# 821                  No             No                 Si
# 822                  Si            Yes                 No
# 823                  No             No                 Si
# 824                  No             No                 Si
#
# [825 rows x 19 columns]

# %%
s1 = pd.DataFrame(s1_copy)
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27           Salesperson             7.5           3.0
# 821    Male   52             Scientist             6.0           8.0
# 822  Female   40                Doctor             8.5           3.0
# 823    Male   45             Scientist             7.0           3.0
# 824    Male   18                Doctor             7.5           5.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# 0       Overweight         126/83        77.0       4200.0            NaN
# 1    Normal Weight         125/80        75.0      10000.0       Insomnia
# 2    Normal Weight         125/80        75.0      10000.0       Insomnia
# 3            Obese         140/90        85.0       3000.0    Sleep Apnea
# 4            Obese         140/90        85.0       3000.0    Sleep Apnea
# ..             ...            ...         ...          ...            ...
# 820     Overweight         140/95        68.0      10000.0    Sleep Apnea
# 821  Normal Weight         125/80        65.0       5000.0       Insomnia
# 822  Normal Weight         120/80        70.0       8000.0    Sleep Apnea
# 823     Overweight         130/85        70.0       6000.0       Insomnia
# 824          Obese         140/90        85.0       3000.0    Sleep Apnea
#
#      sleep_efficiency  rem_sleep_percentage  deep_sleep_percentage  \
# 0                0.80                 28.57                  56.12
# 1                0.80                 19.15                  63.83
# 2                0.80                 26.67                  57.14
# 3                0.40                 22.53                  54.53
# 4                0.40                 22.53                  54.53
# ..                ...                   ...                    ...
# 820              0.91                 22.00                  57.00
# 821              0.74                 28.00                  57.00
# 822              0.55                 20.00                  32.00
# 823              0.76                 18.00                  72.00
# 824              0.63                 22.00                  23.00
#
#      light_sleep_percentage  awakenings caffeine_consumption  \
# 0                     15.31         2.0                   No
# 1                     17.02         3.0                   Si
# 2                     16.19         1.0                   No
# 3                     22.94         1.0                   No
# 4                     22.94         1.0                   No
# ..                      ...         ...                  ...
# 820                   21.00         0.0                   No
# 821                   15.00         4.0                   Si
# 822                   48.00         1.0                   Si
# 823                   10.00         3.0                   No
# 824                   55.00         1.0                   Si
#
#     alcohol_consumption smoking_status exercise_frequency
# 0                    No            Yes                 Si
# 1                    No            Yes                 Si
# 2                    No             No                 Si
# 3                    No             No                 Si
# 4                    No             No                 Si
# ..                  ...            ...                ...
# 820                  No             No                 Si
# 821                  No             No                 Si
# 822                  Si            Yes                 No
# 823                  No             No                 Si
# 824                  No             No                 Si
#
# [825 rows x 19 columns]

# %%
s1.isna().sum()
# Out:
# gender                     0
# age                        0
# occupation                 0
# sleep_duration             0
# stress_level               0
# bmi_category               0
# blood_pressure             0
# heart_rate                 0
# daily_steps                0
# sleep_disorder            39
# sleep_efficiency           0
# rem_sleep_percentage       0
# deep_sleep_percentage      0
# light_sleep_percentage     0
# awakenings                 0
# caffeine_consumption       0
# alcohol_consumption        0
# smoking_status             0
# exercise_frequency         0
# dtype: int64

# %%
import pandas as pd
import numpy as np

# Supongamos que tienes un DataFrame llamado 'df'

# Obtén los tipos únicos de valores en la columna sleep_disorder
valores_unicos = s1['sleep_disorder'].unique()

# Reemplaza los NaN por valores únicos aleatorios
s1['sleep_disorder'] = s1['sleep_disorder'].apply(lambda x: np.random.choice(valores_unicos) if pd.isna(x) else x)

# Reemplaza cualquier NaN restante con un valor único aleatorio
valores_unicos = s1['sleep_disorder'].unique()
s1['sleep_disorder'].fillna(np.random.choice(valores_unicos), inplace=True)

# Mostrar el DataFrame resultante
print(s1)
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27           Salesperson             7.5           3.0
# 821    Male   52             Scientist             6.0           8.0
# 822  Female   40                Doctor             8.5           3.0
# 823    Male   45             Scientist             7.0           3.0
# 824    Male   18                Doctor             7.5           5.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# 0       Overweight         126/83        77.0       4200.0       Insomnia
# 1    Normal Weight         125/80        75.0      10000.0       Insomnia
# 2    Normal Weight         125/80        75.0      10000.0       Insomnia
# 3            Obese         140/90        85.0       3000.0    Sleep Apnea
# 4            Obese         140/90        85.0       3000.0    Sleep Apnea
# ..             ...            ...         ...          ...            ...
# 820     Overweight         140/95        68.0      10000.0    Sleep Apnea
# 821  Normal Weight         125/80        65.0       5000.0       Insomnia
# 822  Normal Weight         120/80        70.0       8000.0    Sleep Apnea
# 823     Overweight         130/85        70.0       6000.0       Insomnia
# 824          Obese         140/90        85.0       3000.0    Sleep Apnea
#
#      sleep_efficiency  rem_sleep_percentage  deep_sleep_percentage  \
# 0                0.80                 28.57                  56.12
# 1                0.80                 19.15                  63.83
# 2                0.80                 26.67                  57.14
# 3                0.40                 22.53                  54.53
# 4                0.40                 22.53                  54.53
# ..                ...                   ...                    ...
# 820              0.91                 22.00                  57.00
# 821              0.74                 28.00                  57.00
# 822              0.55                 20.00                  32.00
# 823              0.76                 18.00                  72.00
# 824              0.63                 22.00                  23.00
#
#      light_sleep_percentage  awakenings caffeine_consumption  \
# 0                     15.31         2.0                   No
# 1                     17.02         3.0                   Si
# 2                     16.19         1.0                   No
# 3                     22.94         1.0                   No
# 4                     22.94         1.0                   No
# ..                      ...         ...                  ...
# 820                   21.00         0.0                   No
# 821                   15.00         4.0                   Si
# 822                   48.00         1.0                   Si
# 823                   10.00         3.0                   No
# 824                   55.00         1.0                   Si
#
#     alcohol_consumption smoking_status exercise_frequency
# 0                    No            Yes                 Si
# 1                    No            Yes                 Si
# 2                    No             No                 Si
# 3                    No             No                 Si
# 4                    No             No                 Si
# ..                  ...            ...                ...
# 820                  No             No                 Si
# 821                  No             No                 Si
# 822                  Si            Yes                 No
# 823                  No             No                 Si
# 824                  No             No                 Si
#
# [825 rows x 19 columns]

# %%
s1
# Out:
#      gender  age            occupation  sleep_duration  stress_level  \
# 0      Male   27     Software Engineer             6.1           6.0
# 1      Male   28                Doctor             6.2           8.0
# 2      Male   28                Doctor             6.2           8.0
# 3      Male   28  Sales Representative             5.9           8.0
# 4      Male   28  Sales Representative             5.9           8.0
# ..      ...  ...                   ...             ...           ...
# 820  Female   27           Salesperson             7.5           3.0
# 821    Male   52             Scientist             6.0           8.0
# 822  Female   40                Doctor             8.5           3.0
# 823    Male   45             Scientist             7.0           3.0
# 824    Male   18                Doctor             7.5           5.0
#
#       bmi_category blood_pressure  heart_rate  daily_steps sleep_disorder  \
# 0       Overweight         126/83        77.0       4200.0       Insomnia
# 1    Normal Weight         125/80        75.0      10000.0       Insomnia
# 2    Normal Weight         125/80        75.0      10000.0       Insomnia
# 3            Obese         140/90        85.0       3000.0    Sleep Apnea
# 4            Obese         140/90        85.0       3000.0    Sleep Apnea
# ..             ...            ...         ...          ...            ...
# 820     Overweight         140/95        68.0      10000.0    Sleep Apnea
# 821  Normal Weight         125/80        65.0       5000.0       Insomnia
# 822  Normal Weight         120/80        70.0       8000.0    Sleep Apnea
# 823     Overweight         130/85        70.0       6000.0       Insomnia
# 824          Obese         140/90        85.0       3000.0    Sleep Apnea
#
#      sleep_efficiency  rem_sleep_percentage  deep_sleep_percentage  \
# 0                0.80                 28.57                  56.12
# 1                0.80                 19.15                  63.83
# 2                0.80                 26.67                  57.14
# 3                0.40                 22.53                  54.53
# 4                0.40                 22.53                  54.53
# ..                ...                   ...                    ...
# 820              0.91                 22.00                  57.00
# 821              0.74                 28.00                  57.00
# 822              0.55                 20.00                  32.00
# 823              0.76                 18.00                  72.00
# 824              0.63                 22.00                  23.00
#
#      light_sleep_percentage  awakenings caffeine_consumption  \
# 0                     15.31         2.0                   No
# 1                     17.02         3.0                   Si
# 2                     16.19         1.0                   No
# 3                     22.94         1.0                   No
# 4                     22.94         1.0                   No
# ..                      ...         ...                  ...
# 820                   21.00         0.0                   No
# 821                   15.00         4.0                   Si
# 822                   48.00         1.0                   Si
# 823                   10.00         3.0                   No
# 824                   55.00         1.0                   Si
#
#     alcohol_consumption smoking_status exercise_frequency
# 0                    No            Yes                 Si
# 1                    No            Yes                 Si
# 2                    No             No                 Si
# 3                    No             No                 Si
# 4                    No             No                 Si
# ..                  ...            ...                ...
# 820                  No             No                 Si
# 821                  No             No                 Si
# 822                  Si            Yes                 No
# 823                  No             No                 Si
# 824                  No             No                 Si
#
# [825 rows x 19 columns]

# %%
s1.sleep_disorder.unique()
# Out:
# array(['Insomnia', 'Sleep Apnea'], dtype=object)

# %%
s1.caffeine_consumption.unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %%
s1.alcohol_consumption.unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %%
s1.exercise_frequency.unique()
# Out:
# array(['Si', 'No'], dtype=object)

# %%
import pandas as pd
s1.pivot_table(index=["bmi_category"],
            
              values=["sleep_duration", "sleep_efficiency"],
              aggfunc='mean')
# Out:
#                sleep_duration  sleep_efficiency
# bmi_category
# Normal Weight        7.440135          0.955000
# Obese                7.356757          0.800631
# Overweight           7.085448          0.887276

# %%
import pandas as pd
s1.pivot_table(index=["bmi_category"],
              columns="smoking_status",
              values=["sleep_duration", "sleep_efficiency", "stress_level"],
              aggfunc='mean')
# Out:
#                awakenings           sleep_duration           sleep_efficiency  \
# smoking_status         No       Yes             No       Yes               No
# bmi_category
# Normal Weight    1.328612  1.827957       7.479037  7.292473         1.009575
# Obese            1.607595  1.687500       7.383544  7.290625         0.821899
# Overweight       1.649746  1.929577       7.104569  7.032394         0.936954
#
#                          stress_level
# smoking_status       Yes           No       Yes
# bmi_category
# Normal Weight   0.747849     4.305949  4.247312
# Obese           0.748125     3.835443  3.968750
# Overweight      0.749437     4.690355  5.140845

# %%
import pandas as pd
s1.pivot_table(index=["bmi_category"],
              columns="caffeine_consumption",
              values=["sleep_duration", "sleep_efficiency", "stress_level", "awakenings"],
              aggfunc='mean')
# Out:
#                      awakenings           sleep_duration            \
# caffeine_consumption         No        Si             No        Si
# bmi_category
# Normal Weight          1.275862  1.724359       7.515862  7.299359
# Obese                  1.639344  1.620000       7.324590  7.396000
# Overweight             1.412162  2.108333       7.258784  6.871667
#
#                      sleep_efficiency           stress_level
# caffeine_consumption               No        Si           No        Si
# bmi_category
# Normal Weight                1.040034  0.796923     4.268966  4.339744
# Obese                        0.797049  0.805000     4.016393  3.700000
# Overweight                   0.970676  0.784417     4.256757  5.491667

# %%
import pandas as pd
s1.pivot_table(index=["bmi_category"],
              columns="alcohol_consumption",
              values=["sleep_duration", "sleep_efficiency", "stress_level", "awakenings"],
              aggfunc='mean')
# Out:
#                     awakenings           sleep_duration            \
# alcohol_consumption         No        Si             No        Si
# bmi_category
# Normal Weight         1.313433  1.792793       7.442388  7.433333
# Obese                 1.449275  1.928571       7.327536  7.404762
# Overweight            1.556122  2.180556       7.025000  7.250000
#
#                     sleep_efficiency           stress_level
# alcohol_consumption               No        Si           No        Si
# bmi_category
# Normal Weight               1.022746  0.750541     4.525373  3.594595
# Obese                       0.839855  0.736190     3.898551  3.833333
# Overweight                  0.943418  0.734444     4.989796  4.319444

# %%
import pandas as pd
s1.pivot_table(index=["bmi_category"],
              columns="exercise_frequency",
              values=["sleep_duration", "sleep_efficiency", "stress_level", "awakenings"],
              aggfunc='mean')
# Out:
#                    awakenings           sleep_duration            \
# exercise_frequency         No        Si             No        Si
# bmi_category
# Normal Weight        1.852459  1.366234       7.754098  7.390390
# Obese                1.666667  1.619048       7.592593  7.280952
# Overweight           2.321429  1.654167       7.250000  7.066250
#
#                    sleep_efficiency           stress_level
# exercise_frequency               No        Si           No        Si
# bmi_category
# Normal Weight              0.753607  0.986909     3.180328  4.470130
# Obese                      0.760000  0.813690     3.407407  4.023810
# Overweight                 0.707143  0.908292     3.678571  4.941667
